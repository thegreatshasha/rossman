# %%
data = read.csv('data/train.csv')
data=as.numeric(data)
# Out:
# Error in eval(expr, envir, enclos): (list) object cannot be coerced to type 'double'

# %% [markdown]
# Now to get the data of stores

# %%
head(data, 5)
# Out:
#   Store DayOfWeek       Date Sales Customers Open Promo StateHoliday
# 1     1         5 2015-07-31  5263       555    1     1            0
# 2     2         5 2015-07-31  6064       625    1     1            0
# 3     3         5 2015-07-31  8314       821    1     1            0
# 4     4         5 2015-07-31 13995      1498    1     1            0
# 5     5         5 2015-07-31  4822       559    1     1            0
#   SchoolHoliday
# 1             1
# 2             1
# 3             1
# 4             1
# 5             1

# %%
store_1 = data[data$Store==1,]
store_2 = data[data$Store==1,]
store_3 = data[data$Store==1,]
store_4 = data[data$Store==1,]
store_5 = data[data$Store==1,]

# %%
nrow(store_1)
nrow(store_2)
nrow(store_3)
nrow(store_4)
nrow(store_5)
# Out:
# [1] 942
# [1] 942
# [1] 942
# [1] 942
# [1] 942

# %%
store_1[31,]
# Out:
#       Store DayOfWeek       Date Sales Customers Open Promo StateHoliday
# 33451     1         3 2015-07-01  5223       562    1     1            0
#       SchoolHoliday
# 33451             0

# %%
store_1[c("DayOfWeek", "Sales")]
# Out:
#         DayOfWeek Sales
# 1               5  5263
# 1116            4  5020
# 2231            3  4782
# 3346            2  5011
# 4461            1  6102
# 5576            7     0
# 6691            6  4364
# 7806            5  3706
# 8921            4  3769
# 10036           3  3464
# 11151           2  3558
# 12266           1  4395
# 13381           7     0
# 14496           6  4406
# 15611           5  4852
# 16726           4  4427
# 17841           3  4767
# 18956           2  5042
# 20071           1  5054
# 21186           7     0
# 22301           6  3530
# 23416           5  3808
# 24531           4  3897
# 25646           3  3797
# 26761           2  3650
# 27876           1  4359
# 28991           7     0
# 30106           6  4797
# 31221           5  4665
# 32336           4  5558
# 33451           3  5223
# 34566           2  5735
# 35681           1  5197
# 36796           7     0
# 37911           6  4019
# 39026           5  3317
# 40141           4  3533
# ...
